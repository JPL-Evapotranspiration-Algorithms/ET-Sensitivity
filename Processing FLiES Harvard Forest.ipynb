# %%
import numpy as np
import pandas as pd
from FLiES_sensitivity import process_FLiES_table

# %%
FLiES_inputs_df = pd.read_csv("ha2_FLiES_inputs.csv")
FLiES_inputs_df
# Out:
#      Unnamed: 0   tower      lat      lon  orbit  scene   tile  \
# 0             0  US-ALQ  46.0308 -89.6067   5391      8  15TYM
# 1             1  US-ALQ  46.0308 -89.6067   7055      8  15TYM
# 2             2  US-ALQ  46.0308 -89.6067  11771      4  15TYM
# 3             3  US-ALQ  46.0308 -89.6067  11862      7  15TYM
# 4             4  US-ALQ  46.0308 -89.6067  11890      9  15TYM
# ..          ...     ...      ...      ...    ...    ...    ...
# 417         679  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 418         680  US-xUN  46.2339 -89.5373   5391      8  15TYM
# 419         681  US-xUN  46.2339 -89.5373   7055      8  15TYM
# 420         685  US-xUN  46.2339 -89.5373  12137      6  15TYM
# 421         686  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
#                 time_UTC    date_UTC               time_solar  ... radiance_5  \
# 0    2019-06-18 00:00:00  2019-06-18  2019-06-17 18:01:34.392  ...        NaN
# ...

# %%
FLiES_inputs_df.columns
# Out:
# Index(['Unnamed: 0', 'tower', 'lat', 'lon', 'orbit', 'scene', 'tile',
#        'time_UTC', 'date_UTC', 'time_solar', 'product', 'NDVI', 'NDVI-UQ',
#        'albedo', 'albedo-UQ', 'BESSinst', 'ESI', 'ESIdaily',
#        'ESIdailyUncertainty', 'ETdaily', 'ETdailyUncertainty',
#        'ETinstUncertainty', 'EmisWB', 'GPP', 'LST', 'LST_err', 'MOD16inst',
#        'PET', 'PTJPLSMcanopy', 'PTJPLSMinst', 'PTJPLSMinterception',
#        'PTJPLSMsoil', 'RH', 'Rg', 'Rn', 'SM', 'STICcanopy', 'STICinst', 'Ta',
#        'WUE', 'elevation_m', 'radiance_1', 'radiance_2', 'radiance_3',
#        'radiance_4', 'radiance_5', 'view_zenith', 'elevation_km', 'doy', 'AOT',
#        'COT', 'vapor_gccm', 'ozone_cm', 'SZA', 'KG'],
#       dtype='object')

# %%
FLiES_outputs_df = process_FLiES_table(FLiES_inputs_df)
FLiES_outputs_df
# Out:
# 14/14 [==============================] - 0s 505us/step
#      Unnamed: 0   tower      lat      lon  orbit  scene   tile  \
# 0             0  US-ALQ  46.0308 -89.6067   5391      8  15TYM
# 1             1  US-ALQ  46.0308 -89.6067   7055      8  15TYM
# 2             2  US-ALQ  46.0308 -89.6067  11771      4  15TYM
# 3             3  US-ALQ  46.0308 -89.6067  11862      7  15TYM
# 4             4  US-ALQ  46.0308 -89.6067  11890      9  15TYM
# ..          ...     ...      ...      ...    ...    ...    ...
# 417         679  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 418         680  US-xUN  46.2339 -89.5373   5391      8  15TYM
# 419         681  US-xUN  46.2339 -89.5373   7055      8  15TYM
# 420         685  US-xUN  46.2339 -89.5373  12137      6  15TYM
# 421         686  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
#                 time_UTC    date_UTC               time_solar  ... NIRdiff  \
# 0    2019-06-18 00:00:00  2019-06-18  2019-06-17 18:01:34.392  ...     NaN
# ...

# %%
FLiES_outputs_df = process_FLiES_table(FLiES_inputs_df)
FLiES_outputs_df.to_csv("ha2_FLiES_outputs.csv")
FLiES_outputs_df
# Out:
# 14/14 [==============================] - 0s 529us/step
#      Unnamed: 0   tower      lat      lon  orbit  scene   tile  \
# 0             0  US-ALQ  46.0308 -89.6067   5391      8  15TYM
# 1             1  US-ALQ  46.0308 -89.6067   7055      8  15TYM
# 2             2  US-ALQ  46.0308 -89.6067  11771      4  15TYM
# 3             3  US-ALQ  46.0308 -89.6067  11862      7  15TYM
# 4             4  US-ALQ  46.0308 -89.6067  11890      9  15TYM
# ..          ...     ...      ...      ...    ...    ...    ...
# 417         679  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 418         680  US-xUN  46.2339 -89.5373   5391      8  15TYM
# 419         681  US-xUN  46.2339 -89.5373   7055      8  15TYM
# 420         685  US-xUN  46.2339 -89.5373  12137      6  15TYM
# 421         686  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
#                 time_UTC    date_UTC               time_solar  ... NIRdiff  \
# 0    2019-06-18 00:00:00  2019-06-18  2019-06-17 18:01:34.392  ...     NaN
# ...

# %%
FLiES_outputs_df.columns
# Out:
# Index(['Unnamed: 0', 'tower', 'lat', 'lon', 'orbit', 'scene', 'tile',
#        'time_UTC', 'date_UTC', 'time_solar', 'product', 'NDVI', 'NDVI-UQ',
#        'albedo', 'albedo-UQ', 'BESSinst', 'ESI', 'ESIdaily',
#        'ESIdailyUncertainty', 'ETdaily', 'ETdailyUncertainty',
#        'ETinstUncertainty', 'EmisWB', 'GPP', 'LST', 'LST_err', 'MOD16inst',
#        'PET', 'PTJPLSMcanopy', 'PTJPLSMinst', 'PTJPLSMinterception',
#        'PTJPLSMsoil', 'RH', 'Rg', 'Rn', 'SM', 'STICcanopy', 'STICinst', 'Ta',
#        'WUE', 'elevation_m', 'radiance_1', 'radiance_2', 'radiance_3',
#        'radiance_4', 'radiance_5', 'view_zenith', 'elevation_km', 'doy', 'AOT',
#        'COT', 'vapor_gccm', 'ozone_cm', 'SZA', 'KG', 'Ra', 'UV', 'VIS', 'NIR',
#        'VISdiff', 'NIRdiff', 'VISdir', 'NIRdir', 'tm', 'puv', 'pvis', 'pnir',
#        'fduv', 'fdvis', 'fdnir'],
#       dtype='object')
