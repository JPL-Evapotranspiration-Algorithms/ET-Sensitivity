# %%
import numpy as np
from rasters import Raster
from MCD12C1 import load_MCD12C1_IGBP
from MOD16.LUT import translate_IGBP

# %%
IGBP = load_MCD12C1_IGBP()
IGBP

# %%
gl_sh = translate_IGBP("gl_sh")
gl_sh

# %%
gl_e_wv = translate_IGBP("gl_e_wv")
gl_e_wv

# %%
rbl_min = translate_IGBP("rbl_min")
rbl_min

# %%
rbl_max = translate_IGBP("rbl_max")
rbl_max

# %%
cl = translate_IGBP("cl")
cl

# %%
tmin_open = translate_IGBP("tmin_open")
tmin_open

# %%
tmin_close = translate_IGBP("tmin_close")
tmin_close

# %%
vpd_close = translate_IGBP("vpd_close")
vpd_close

# %%
vpd_open = translate_IGBP("vpd_open")
vpd_open
