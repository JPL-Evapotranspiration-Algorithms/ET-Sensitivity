# %%
import pandas as pd

# %%
samples = pd.read_csv("calval_final_50.csv")
samples
# Out:
#        Unnamed: 0   tower  orbit  scene   tile             time_UTC   product  \
# 0               0  US-Mpj   3190      4  13SCU  2019-01-27 23:32:30  L1CT_RAD
# 1               1  US-Mpj   3190      4  13SCU  2019-01-27 23:32:30  L1CT_RAD
# 2               2  US-Mpj   3190      4  13SCU  2019-01-27 23:32:30  L1CT_RAD
# 3               3  US-Mpj   3190      4  13SCU  2019-01-27 23:32:30  L1CT_RAD
# 4               4  US-Mpj   3190      4  13SCU  2019-01-27 23:32:30  L1CT_RAD
# ...           ...     ...    ...    ...    ...                  ...       ...
# 68894       68894  US-Ha2  19605     12  18TYN  2021-12-20 17:05:33   L4T_WUE
# 68895       68895  US-Ha2  19605     12  18TYN  2021-12-20 17:05:33   L4T_WUE
# 68896       68896  US-Ha2  19620     13  18TYN  2021-12-21 16:18:05   L3T_MET
# 68897       68897  US-Ha2  19620     13  18TYN  2021-12-21 16:18:05   L3T_MET
# 68898       68898  US-Ha2  19620     13  18TYN  2021-12-21 16:18:05    L3T_SM
#
# ...

# %%
sites_df = samples.groupby("tower")[["lat", "lon"]].first().reset_index()
sites_df.to_csv("sites.csv", index=False)
sites_df
# Out:
#      tower      lat       lon
# 0   CA-Cbo  44.3167  -79.9333
# 1   CA-DB2  49.1190 -122.9951
# 2   PR-xGU  17.9696  -66.8687
# 3   PR-xLA  18.0212  -67.0769
# 4   US-ALQ  46.0308  -89.6067
# 5   US-CF1  46.7815 -117.0821
# 6   US-CF2  46.7840 -117.0908
# 7   US-CF3  46.7551 -117.1261
# 8   US-CF4  46.7518 -117.1285
# 9   US-CS2  44.1467  -89.5002
# 10  US-DFC  43.3448  -89.7117
# 11  US-GLE  41.3665 -106.2399
# 12  US-Ha2  42.5393  -72.1779
# 13  US-KM4  42.4423  -85.3301
# 14  US-Los  46.0827  -89.9792
# 15  US-Me6  44.3233 -121.6078
# 16  US-Mpj  34.4385 -106.2377
# 17  US-NC2  35.8030  -76.6685
# 18  US-NC3  35.7990  -76.6560
# 19  US-NC4  35.7879  -75.9038
# 20  US-NR1  40.0329 -105.5464
# 21  US-NR3  40.0520 -105.5864
# 22  US-ONA  27.3836  -81.9509
# 23  US-PFd  45.9689  -90.3010
# 24  US-PFi  45.9749  -90.2327
# 25  US-PFq  45.9271  -90.2475
# 26  US-PHM  42.7423  -70.8301
# 27  US-Ro4  44.6781  -93.0723
# 28  US-Syv  46.2420  -89.3477
# 29  US-Tw1  38.1074 -121.6469
# ...
