# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
new_model = pd.read_csv("calval_final_50_FLiES_outputs.csv")
new_model
# Out:
#      Unnamed: 0.1   tower      lat      lon  orbit  scene   tile  \
# 0               0  US-Ha2  42.5393 -72.1779   9254      9  18TYN
# 1               1  US-Ha2  42.5393 -72.1779  10150      9  18TYN
# 2               2  US-Ha2  42.5393 -72.1779  10352      9  18TYN
# 3               3  US-Ha2  42.5393 -72.1779  10684      7  18TYN
# 4               4  US-Ha2  42.5393 -72.1779  11069      8  18TYN
# ..            ...     ...      ...      ...    ...    ...    ...
# 247           247  US-xUK  39.0404 -95.1921  11909      6  15SUD
# 248           248  US-xUK  39.0404 -95.1921  16668      8  15SUD
# 249           249  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 250           250  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 251           251  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
#                 time_UTC    date_UTC  doy  ...   ST_C  elevation_km  \
# 0    2020-02-22 00:00:00  2020-02-22   53  ...   0.89         0.058
# ...

# %%
new_model.columns
# Out:
# Index(['Unnamed: 0.1', 'tower', 'lat', 'lon', 'orbit', 'scene', 'tile',
#        'time_UTC', 'date_UTC', 'doy', 'time_solar', 'AOT', 'COT', 'vapor_gccm',
#        'ozone_cm', 'SZA', 'KG', 'Unnamed: 0', 'lat_Y', 'lon_Y', 'orbit_Y',
#        'scene_Y', 'tile_Y', 'time_UTC_Y', 'time_solar_Y', 'BESSinst', 'ESI',
#        'ESIdaily', 'ESIdailyUncertainty', 'ETdaily', 'ETdailyUncertainty',
#        'ETinstUncertainty', 'EmisWB', 'GPP', 'LST', 'LST_err', 'MOD16inst',
#        'NDVI-UQ', 'PET', 'PTJPLSMcanopy', 'PTJPLSMinst', 'PTJPLSMinterception',
#        'PTJPLSMsoil', 'RH', 'Rg', 'Rn', 'SM', 'STICcanopy', 'STICinst', 'Ta',
#        'WUE', 'albedo-UQ', 'height', 'radiance_1', 'radiance_2', 'radiance_3',
#        'radiance_4', 'radiance_5', 'view_zenith', 'year', 'Ta_C', 'ST_K',
#        'NDVI', 'albedo', 'ST_C', 'elevation_km', 'Ra', 'UV', 'VIS', 'NIR',
#        'VISdiff', 'NIRdiff', 'VISdir', 'NIRdir'],
#       dtype='object')

# %%
old_model = pd.read_csv("calval_final_50_FLiES_outputs_oldmodel.csv")
old_model
# Out:
#      Unnamed: 0.1   tower      lat      lon  orbit  scene   tile  \
# 0               0  US-Ha2  42.5393 -72.1779   9254      9  18TYN
# 1               1  US-Ha2  42.5393 -72.1779  10150      9  18TYN
# 2               2  US-Ha2  42.5393 -72.1779  10352      9  18TYN
# 3               3  US-Ha2  42.5393 -72.1779  10684      7  18TYN
# 4               4  US-Ha2  42.5393 -72.1779  11069      8  18TYN
# ..            ...     ...      ...      ...    ...    ...    ...
# 247           247  US-xUK  39.0404 -95.1921  11909      6  15SUD
# 248           248  US-xUK  39.0404 -95.1921  16668      8  15SUD
# 249           249  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 250           250  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 251           251  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
#                 time_UTC    date_UTC  doy  ...   ST_C  elevation_km  \
# 0    2020-02-22 00:00:00  2020-02-22   53  ...   0.89         0.058
# ...

# %%
plt.scatter(x=old_model.Rg, y=new_model.Rg)

# %%
baseline = pd.read_csv("calval_final_50_FLiES_outputs_baseline.csv")
baseline
# Out:
#      Unnamed: 0.1   tower      lat      lon  orbit  scene   tile  \
# 0               0  US-Ha2  42.5393 -72.1779   9254      9  18TYN
# 1               1  US-Ha2  42.5393 -72.1779  10150      9  18TYN
# 2               2  US-Ha2  42.5393 -72.1779  10352      9  18TYN
# 3               3  US-Ha2  42.5393 -72.1779  10684      7  18TYN
# 4               4  US-Ha2  42.5393 -72.1779  11069      8  18TYN
# ..            ...     ...      ...      ...    ...    ...    ...
# 247           247  US-xUK  39.0404 -95.1921  11909      6  15SUD
# 248           248  US-xUK  39.0404 -95.1921  16668      8  15SUD
# 249           249  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 250           250  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 251           251  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
#                 time_UTC    date_UTC  doy  ...   ST_C  elevation_km  \
# 0    2020-02-22 00:00:00  2020-02-22   53  ...   0.89         0.058
# ...

# %%
plt.scatter(x=new_model.Rg, y=baseline.Rg)
