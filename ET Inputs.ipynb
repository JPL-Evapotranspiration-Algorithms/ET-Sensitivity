# %%
import pandas as pd
from PTJPL_sensitivity import generate_PTJPL_inputs, process_PTJPL_table

# %%
net_radiation_df = pd.read_csv("calval_final_50_FLiES_outputs.csv")
net_radiation_df
# Out:
#      Unnamed: 0.1  Unnamed: 0   tower      lat      lon  orbit  scene   tile  \
# 0               0           0  US-ALQ  46.0308 -89.6067   5391      8  15TYM
# 1               1           1  US-ALQ  46.0308 -89.6067   7055      8  15TYM
# 2               2           2  US-ALQ  46.0308 -89.6067  11771      4  15TYM
# 3               3           3  US-ALQ  46.0308 -89.6067  11862      7  15TYM
# 4               4           4  US-ALQ  46.0308 -89.6067  11890      9  15TYM
# ..            ...         ...     ...      ...      ...    ...    ...    ...
# 417           417         679  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 418           418         680  US-xUN  46.2339 -89.5373   5391      8  15TYM
# 419           419         681  US-xUN  46.2339 -89.5373   7055      8  15TYM
# 420           420         685  US-xUN  46.2339 -89.5373  12137      6  15TYM
# 421           421         686  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
# ...

# %%
inputs_df = generate_PTJPL_inputs(net_radiation_df)
inputs_df.to_csv("calval_final_50_PTJPL_inputs.csv", index=False)
inputs_df
# Out:
# [2023-12-04 14:06:48 INFO] collecting PTJPL inputs for tower US-ALQ lat 46.0308 lon -89.6067 time 2019-06-18 00:00:00 UTC
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Projects/ET-Sensitivity/sentinel_tile_grid/sentinel_tile_grid.py:207, in SentinelTileGrid.footprint(self, tile, in_UTM, round_UTM, in_2d)
#     206 try:
# --> 207     polygon = Polygon(self.sentinel_polygons[self.sentinel_polygons.Name == tile].iloc[0]["geometry"], crs=self.crs)
#     208 except Exception as e:
#
# File ~/miniforge-pypy3/envs/sensitivity/lib/python3.9/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
outputs_df = process_PTJPL_table(inputs_df)
outputs_df
# Out:
#     Unnamed: 0.1  Unnamed: 0   tower      lat      lon        time_UTC
# 0              0           4  US-Ha2  42.5393 -72.1779   4/20/20 11:54  \
# 1              1           7  US-Ha2  42.5393 -72.1779   4/29/20 14:28
# 2              2          13  US-Ha2  42.5393 -72.1779   6/18/20 18:47
# 3              3          16  US-Ha2  42.5393 -72.1779   6/19/20 18:00
# 4              4          19  US-Ha2  42.5393 -72.1779   6/21/20 11:31
# 5              5          22  US-Ha2  42.5393 -72.1779   6/22/20 17:13
# 6              6          25  US-Ha2  42.5393 -72.1779   6/23/20 16:25
# 7              7          28  US-Ha2  42.5393 -72.1779    7/4/20 12:28
# 8              8          31  US-Ha2  42.5393 -72.1779   7/25/20 22:08
# 9              9          34  US-Ha2  42.5393 -72.1779   7/29/20 20:33
# 10            10          37  US-Ha2  42.5393 -72.1779   8/10/20 15:53
# 11            11          40  US-Ha2  42.5393 -72.1779   8/20/20 17:39
# ...
